# %%
import pandas as pd

# %%
df_lobbyists = pd.read_csv("./data/silver/df_lobbyists.csv")

# %%
df_lobbyists.head()
# Out:
#        lobbyist_id l_registration_date l_category l_head_office_country  \
# 0  861854150361-39          02/06/2023       NGOs                POLAND
# 1  680025443289-14          23/06/2021       NGOs               HUNGARY
# 2  610631350643-79          30/06/2023   Business               BELGIUM
# 3  381757951712-94          07/11/2023   Business                SWEDEN
# 4  625735349859-48          18/04/2023       NGOs                FRANCE
#
#    l_agriculture  l_economics_and_trade  l_education  \
# 0              0                      0            1
# 1              1                      1            1
# 2              1                      1            1
# 3              0                      1            0
# 4              0                      0            1
#
#    l_environment_and_climate  l_foreign_and_security_affairs  l_health  \
# 0                          0                               0         0
# ...
