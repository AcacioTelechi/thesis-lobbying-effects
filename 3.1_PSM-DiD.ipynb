# %%
import pandas as pd
import statsmodels.api as sm

from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np

from sklearn.neighbors import NearestNeighbors

# %%
# Find and remove highly correlated features
def remove_collinear_features(X: pd.DataFrame, threshold=0.95):
    corr_matrix = X.corr().abs()
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
    print("to_drop", to_drop)
    return X.drop(to_drop, axis=1)


def calculate_vif(X: pd.DataFrame):
    vif_data = pd.DataFrame()
    vif_data["Variable"] = X.columns
    vif_data["VIF"] = [
        variance_inflation_factor(X.values, i) for i in range(X.shape[1])
    ]
    return vif_data

# %%
df = pd.read_csv("./data/gold/panel_data_treated.csv")
df_cross = pd.read_csv("./data/gold/cross_section.csv")

df["date"] = pd.to_datetime(df["date"])
# Out:
# C:\Users\caca_\AppData\Local\Temp\ipykernel_15644\381178250.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./data/gold/panel_data_treated.csv")

# %%
important_columns = [
    'mep_id',
    'meetings',
    'questions_log'
]
country_columns = [c for c in df_cross.columns if 'country' in c]
p_groups_columns = [c for c in df_cross.columns if 'political_group' in c]
membership_columns = [c for c in df_cross.columns if c not in columns_to_keep][2:]

columns_to_keep = important_columns + country_columns + p_groups_columns + membership_columns

# %%
x_columns_psm
# Out:
# ['questions_log',
#  'country_0',
#  'country_AUT',
#  'country_BEL',
#  'country_BGR',
#  'country_CYP',
#  'country_CZE',
#  'country_DEU',
#  'country_DNK',
#  'country_ESP',
#  'country_EST',
#  'country_FIN',
#  'country_GBR',
#  'country_GRC',
#  'country_HRV',
#  'country_HUN',
#  'country_IRL',
#  'country_ITA',
#  'country_LTU',
#  'country_LUX',
#  'country_LVA',
#  'country_MLT',
#  'country_NLD',
#  'country_POL',
#  'country_PRT',
#  'country_ROU',
#  'country_SVK',
#  'country_SVN',
#  'country_SWE',
#  'political_group_1533',
#  'political_group_1534',
#  'political_group_1537',
#  'political_group_1538',
#  'political_group_1539',
#  'political_group_1541',
#  'political_group_1550',
#  'political_group_1554',
#  'political_group_3968',
#  'political_group_4273',
#  'political_group_4275',
#  'political_group_4280',
#  'political_group_4281',
#  'political_group_4283',
#  'political_group_4284',
#  'political_group_4285',
#  'political_group_4880',
#  'political_group_4908',
#  'political_group_5148',
#  'political_group_5151',
#  'political_group_5152',
#  'political_group_5153',
#  'political_group_5154',
#  'political_group_5155',
#  'political_group_5588',
#  'political_group_5704',
#  'political_group_6259',
#  'political_group_6561',
#  'political_group_7018',
#  'political_group_7028',
#  'political_group_7035',
#  'political_group_7036',
#  'political_group_7037',
#  'political_group_7038',
#  'political_group_7150',
#  'political_group_7151',
#  'COMMITTEE_PARLIAMENTARY_STANDING',
#  'COMMITTEE_PARLIAMENTARY_SUB',
#  'COMMITTEE_PARLIAMENTARY_TEMPORARY',
#  'DELEGATION_JOINT_COMMITTEE',
#  'DELEGATION_PARLIAMENTARY',
#  'DELEGATION_PARLIAMENTARY_ASSEMBLY',
#  'WORKING_GROUP']

# %%
# Run a PSM analysis
df_psm = df_cross.copy()[columns_to_keep]
# # Create treatment and control groups
df_psm["treatment"] = (df_psm["meetings"] > 0).astype(int)

# Prepare features for PSM
x_columns_psm = columns_to_keep[2:]

X_psm = df_psm[x_columns_psm].copy()
y_psm = df_psm["treatment"]

# Fit logistic regression for propensity scores
logit = sm.Logit(y_psm, sm.add_constant(X_psm))
logit_fit = logit.fit()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.319766
#          Iterations: 35
# C:\Users\caca_\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
logit_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              treatment   No. Observations:                 1353
# Model:                          Logit   Df Residuals:                     1281
# Method:                           MLE   Df Model:                           71
# Date:                Mon, 17 Mar 2025   Pseudo R-squ.:                  0.5386
# Time:                        16:49:01   Log-Likelihood:                -432.64
# converged:                      False   LL-Null:                       -937.77
# Covariance Type:            nonrobust   LLR p-value:                4.847e-166
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# questions_log                        -0.0410      0.107     -0.385      0.701      -0.250       0.168
# country_0                            -0.7280      1.180     -0.617      0.537      -3.042       1.586
# country_AUT                           0.4050      0.649      0.624      0.532      -0.866       1.676
# country_BEL                           0.5603      0.571      0.981      0.327      -0.559       1.679
# country_BGR                          -1.1744      0.666     -1.763      0.078      -2.480       0.131
# country_CYP                          -1.9605      1.023     -1.917      0.055      -3.965       0.044
# country_CZE                          -0.7221      0.548     -1.319      0.187      -1.795       0.351
# country_DEU                           0.4751      0.431      1.101      0.271      -0.370       1.321
# country_DNK                           0.3865      0.724      0.534      0.594      -1.033       1.806
# country_ESP                          -0.3104      0.436     -0.712      0.477      -1.165       0.545
# country_EST                          -1.0349      1.315     -0.787      0.431      -3.613       1.543
# country_FIN                           0.9908      0.718      1.381      0.167      -0.416       2.397
# country_GBR                          -4.1710      0.831     -5.017      0.000      -5.800      -2.541
# country_GRC                          -1.6990      0.620     -2.742      0.006      -2.913      -0.485
# country_HRV                          -1.8000      0.992     -1.815      0.070      -3.744       0.144
# country_HUN                           0.9676      0.636      1.520      0.128      -0.280       2.215
# country_IRL                          -0.2298      0.794     -0.290      0.772      -1.786       1.326
# country_ITA                          -0.2031      0.357     -0.570      0.569      -0.902       0.496
# country_LTU                          -2.2716      0.793     -2.865      0.004      -3.826      -0.717
# country_LUX                           1.2014      1.121      1.072      0.284      -0.995       3.398
# country_LVA                           0.0943      0.930      0.101      0.919      -1.727       1.916
# country_MLT                           1.5236      1.483      1.028      0.304      -1.382       4.429
# country_NLD                           0.0371      0.506      0.073      0.942      -0.955       1.029
# country_POL                          -0.4167      0.429     -0.971      0.331      -1.257       0.424
# country_PRT                          -0.3161      0.524     -0.603      0.547      -1.344       0.712
# country_ROU                          -0.7345      0.559     -1.313      0.189      -1.831       0.362
# country_SVK                          -0.4341      0.646     -0.672      0.501      -1.699       0.831
# country_SVN                           0.3823      1.017      0.376      0.707      -1.611       2.375
# country_SWE                           0.6565      0.601      1.092      0.275      -0.522       1.835
# political_group_1533                 -0.0657      0.555     -0.118      0.906      -1.154       1.023
# political_group_1534                 -0.0669      0.637     -0.105      0.916      -1.315       1.181
# political_group_1537                -59.0777   8.24e+12  -7.17e-12      1.000   -1.61e+13    1.61e+13
# political_group_1538                 -1.5684      1.933     -0.811      0.417      -5.357       2.220
# political_group_1539                 -0.9195      1.017     -0.904      0.366      -2.912       1.073
# political_group_1541                -18.1505   2.21e+04     -0.001      0.999   -4.34e+04    4.34e+04
# political_group_1550                  0.3128      0.832      0.376      0.707      -1.318       1.943
# political_group_1554                -34.3633    3.9e+07   -8.8e-07      1.000   -7.65e+07    7.65e+07
# political_group_3968                 -1.6945      0.777     -2.180      0.029      -3.218      -0.171
# political_group_4273                 -1.5093      0.406     -3.715      0.000      -2.306      -0.713
# political_group_4275                 -1.5056      0.558     -2.698      0.007      -2.599      -0.412
# political_group_4280                  3.2703      2.925      1.118      0.264      -2.463       9.004
# political_group_4281                 -1.2209      0.782     -1.562      0.118      -2.753       0.311
# political_group_4283                 -2.4748      0.681     -3.634      0.000      -3.810      -1.140
# political_group_4284                 -1.8040      0.470     -3.838      0.000      -2.725      -0.883
# political_group_4285                 -1.7247      0.957     -1.802      0.071      -3.600       0.151
# political_group_4880                 -2.3038      2.841     -0.811      0.417      -7.872       3.264
# political_group_4908                  0.5981      0.810      0.738      0.460      -0.990       2.186
# political_group_5148                  2.1729      0.469      4.634      0.000       1.254       3.092
# political_group_5151                  1.0130      1.230      0.823      0.410      -1.398       3.424
# political_group_5152                  0.1958      0.407      0.481      0.630      -0.602       0.993
# political_group_5153                  2.3476      0.401      5.854      0.000       1.562       3.134
# political_group_5154                  3.2039      0.495      6.476      0.000       2.234       4.174
# political_group_5155                  5.9012      1.045      5.649      0.000       3.854       7.949
# political_group_5588                  0.6930      0.447      1.550      0.121      -0.183       1.569
# political_group_5704                  4.2547      0.617      6.898      0.000       3.046       5.464
# political_group_6259                  3.1127      1.127      2.762      0.006       0.904       5.321
# political_group_6561                  1.2213      0.584      2.091      0.037       0.077       2.366
# political_group_7018                  1.7839      0.333      5.352      0.000       1.131       2.437
# political_group_7028                  1.9080      0.621      3.072      0.002       0.691       3.125
# political_group_7035                  3.0819      0.549      5.612      0.000       2.006       4.158
# political_group_7036                  2.2903      0.567      4.039      0.000       1.179       3.402
# political_group_7037                  0.8463      0.396      2.139      0.032       0.071       1.622
# political_group_7038                  2.4755      0.383      6.464      0.000       1.725       3.226
# political_group_7150                  1.3915      0.394      3.530      0.000       0.619       2.164
# political_group_7151                 -0.1168      0.633     -0.184      0.854      -1.358       1.124
# COMMITTEE_PARLIAMENTARY_STANDING     -2.5626      1.410     -1.817      0.069      -5.327       0.201
# COMMITTEE_PARLIAMENTARY_SUB          -0.2172      0.200     -1.086      0.277      -0.609       0.175
# COMMITTEE_PARLIAMENTARY_TEMPORARY     0.5361      0.245      2.184      0.029       0.055       1.017
# DELEGATION_JOINT_COMMITTEE            0.2227      0.194      1.147      0.252      -0.158       0.603
# DELEGATION_PARLIAMENTARY              1.9467      0.622      3.129      0.002       0.727       3.166
# DELEGATION_PARLIAMENTARY_ASSEMBLY    -0.1401      0.198     -0.706      0.480      -0.529       0.249
# WORKING_GROUP                         0.9835      0.315      3.121      0.002       0.366       1.601
# =====================================================================================================
# """

# %%
# Calculate propensity scores
df_psm["propensity_score"] = logit_fit.predict()

# Separate treatment and control
treatment = df_psm[df_psm["treatment"] == 1]
control = df_psm[df_psm["treatment"] == 0]

# Find nearest neighbors
nbrs = NearestNeighbors(n_neighbors=1).fit(control[["propensity_score"]])
distances, indices = nbrs.kneighbors(treatment[["propensity_score"]])

# Get matched control group
matched_control = control.iloc[indices.flatten()]

# Combine matched samples
matched_df_psm = pd.concat([treatment, matched_control])


# Check balance of covariates
def check_balance(df_psm, features, treatment_col="treatment"):
    balance_stats = []
    for feature in features:
        treated_mean = df_psm[df_psm[treatment_col] == 1][feature].mean()
        control_mean = df_psm[df_psm[treatment_col] == 0][feature].mean()
        std_diff = (treated_mean - control_mean) / np.sqrt(
            (
                df_psm[df_psm[treatment_col] == 1][feature].var()
                + df_psm[df_psm[treatment_col] == 0][feature].var()
            )
            / 2
        )
        balance_stats.append(
            {
                "Feature": feature,
                "Treated Mean": treated_mean,
                "Control Mean": control_mean,
                "Std Diff": std_diff,
            }
        )
    return pd.DataFrame(balance_stats)


# Print balance statistics
print("\nCovariate Balance After Matching:")
check_balance(matched_df_psm, x_columns_psm)
# Out:
# Covariate Balance After Matching:
# C:\Users\caca_\AppData\Local\Temp\ipykernel_15644\1223811495.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   std_diff = (treated_mean - control_mean) / np.sqrt(
#                               Feature  Treated Mean  Control Mean  Std Diff
# 0                       questions_log      3.536373      3.547898 -0.008410
# 1                           country_0      0.976119      0.964179  0.070155
# 2                         country_AUT      0.028358      0.008955  0.143660
# 3                         country_BEL      0.035821      0.011940  0.156776
# 4                         country_BGR      0.019403      0.062687 -0.219316
# ..                                ...           ...           ...       ...
# 67  COMMITTEE_PARLIAMENTARY_TEMPORARY      0.365672      0.341791  0.049924
# 68         DELEGATION_JOINT_COMMITTEE      0.428358      0.374627  0.109694
# 69           DELEGATION_PARLIAMENTARY      0.988060      0.977612  0.080445
# 70  DELEGATION_PARLIAMENTARY_ASSEMBLY      0.652239      0.577612  0.153698
# 71                      WORKING_GROUP      0.644776      0.673134 -0.059802
#
# [72 rows x 4 columns]

# %% [markdown]
# # DID

# %%
df_did = df[df['mep_id'].isin(matched_df_psm.index)]

# %% [markdown]
# ## DID regression

# %%
# Now, run a regression with fixed effects
from linearmodels import PanelOLS

# %%
# Set the index for panel data
df_panel = df_did.set_index(["mep_id", "date"])


# Set columns list
important_columns = [
    "quetions_log",
    # 'meetings',
    "treatment",
    "received_treatment_and_started",
]
country_columns = [c for c in df_panel.columns if "country" in c]
p_groups_columns = [c for c in df_panel.columns if "political_group" in c]
membership_columns = [
    c
    for c in df_panel.columns
    if c not in [*important_columns, *country_columns, *p_groups_columns]
    and c not in ["EU_INSTITUTION", "EU_POLITICAL_GROUP", "NATIONAL_CHAMBER"]
][8:]

columns_to_keep = (
    important_columns + country_columns + p_groups_columns + membership_columns
)


# Prepare dependent and independent variables
Y = df_panel['quetions_log']
X = df_panel[columns_to_keep[1:]]

# X = X.drop(to_drop_colinear_columns, axis=1)

model = sm.OLS(Y, sm.add_constant(X))

results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           quetions_log   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     22.42
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           3.83e-66
# Time:                        16:58:07   Log-Likelihood:                 45519.
# No. Observations:               31790   AIC:                        -9.100e+04
# Df Residuals:                   31773   BIC:                        -9.086e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                              1.714e+08   1.18e+10      0.015      0.988   -2.29e+10    2.32e+10
# treatment                          1.096e-05      0.024      0.000      1.000      -0.046       0.046
# received_treatment_and_started       -0.0078      0.003     -2.414      0.016      -0.014      -0.001
# country_0                         -1.714e+08   1.18e+10     -0.015      0.988   -2.32e+10    2.29e+10
# country_AUT                       -2.241e-07   1.54e-05     -0.015      0.988   -3.04e-05    2.99e-05
# country_BEL                        2.305e-07   1.58e-05      0.015      0.988   -3.08e-05    3.12e-05
# country_BGR                       -1.793e-07   1.23e-05     -0.015      0.988   -2.43e-05    2.39e-05
# country_CYP                        1.281e-07   8.79e-06      0.015      0.988   -1.71e-05    1.74e-05
# country_CZE                        5.123e-08   3.52e-06      0.015      0.988   -6.84e-06    6.94e-06
# country_DEU                          -0.0030      0.002     -1.688      0.091      -0.006       0.000
# country_DNK                        8.965e-08   6.15e-06      0.015      0.988    -1.2e-05    1.21e-05
# country_ESP                        5.123e-08   3.52e-06      0.015      0.988   -6.84e-06    6.94e-06
# country_EST                       -5.123e-08   3.52e-06     -0.015      0.988   -6.94e-06    6.84e-06
# country_FIN                        1.281e-08   8.79e-07      0.015      0.988   -1.71e-06    1.74e-06
# country_GBR                        1.281e-08   8.79e-07      0.015      0.988   -1.71e-06    1.74e-06
# country_GRC                       -1.281e-08   8.79e-07     -0.015      0.988   -1.74e-06    1.71e-06
# country_HRV                        8.781e-19   1.45e-19      6.051      0.000    5.94e-19    1.16e-18
# country_HUN                                0          0        nan        nan           0           0
# country_IRL                                0          0        nan        nan           0           0
# country_ITA                       -8.569e+07   5.88e+09     -0.015      0.988   -1.16e+10    1.14e+10
# country_LTU                                0          0        nan        nan           0           0
# country_LUX                       -1.285e+08   8.82e+09     -0.015      0.988   -1.74e+10    1.72e+10
# country_LVA                                0          0        nan        nan           0           0
# country_MLT                                0          0        nan        nan           0           0
# country_NLD                                0          0        nan        nan           0           0
# country_POL                                0          0        nan        nan           0           0
# country_PRT                                0          0        nan        nan           0           0
# country_ROU                                0          0        nan        nan           0           0
# country_SVK                                0          0        nan        nan           0           0
# country_SVN                                0          0        nan        nan           0           0
# country_SWE                                0          0        nan        nan           0           0
# political_group_1533              -1.714e+08   1.18e+10     -0.015      0.988   -2.32e+10    2.29e+10
# political_group_1534                       0          0        nan        nan           0           0
# political_group_1537                       0          0        nan        nan           0           0
# political_group_1538                       0          0        nan        nan           0           0
# political_group_1539              -8.569e+07   5.88e+09     -0.015      0.988   -1.16e+10    1.14e+10
# political_group_1541              -1.714e+08   1.18e+10     -0.015      0.988   -2.32e+10    2.29e+10
# political_group_1550                       0          0        nan        nan           0           0
# political_group_1554                       0          0        nan        nan           0           0
# political_group_3968              -1.714e+08   1.18e+10     -0.015      0.988   -2.32e+10    2.29e+10
# political_group_4273              -1.714e+08   1.18e+10     -0.015      0.988   -2.32e+10    2.29e+10
# political_group_4275                       0          0        nan        nan           0           0
# political_group_4280                       0          0        nan        nan           0           0
# political_group_4281                       0          0        nan        nan           0           0
# political_group_4283              -4.284e+07   2.94e+09     -0.015      0.988    -5.8e+09    5.72e+09
# political_group_4284                       0          0        nan        nan           0           0
# political_group_4285                       0          0        nan        nan           0           0
# political_group_4880                       0          0        nan        nan           0           0
# political_group_4908                       0          0        nan        nan           0           0
# political_group_5148                       0          0        nan        nan           0           0
# political_group_5151                       0          0        nan        nan           0           0
# political_group_5152                       0          0        nan        nan           0           0
# political_group_5153                       0          0        nan        nan           0           0
# political_group_5154                       0          0        nan        nan           0           0
# political_group_5155                       0          0        nan        nan           0           0
# political_group_5588                       0          0        nan        nan           0           0
# political_group_5704              -4.284e+07   2.94e+09     -0.015      0.988    -5.8e+09    5.72e+09
# political_group_6259                       0          0        nan        nan           0           0
# political_group_6561                       0          0        nan        nan           0           0
# political_group_7018                       0          0        nan        nan           0           0
# political_group_7028                       0          0        nan        nan           0           0
# political_group_7035              -4.284e+07   2.94e+09     -0.015      0.988    -5.8e+09    5.72e+09
# political_group_7036                       0          0        nan        nan           0           0
# political_group_7037                       0          0        nan        nan           0           0
# political_group_7038                       0          0        nan        nan           0           0
# political_group_7150                       0          0        nan        nan           0           0
# political_group_7151                       0          0        nan        nan           0           0
# COMMITTEE_PARLIAMENTARY_TEMPORARY     0.0012      0.002      0.603      0.547      -0.003       0.005
# DELEGATION_JOINT_COMMITTEE           -0.0064      0.002     -2.791      0.005      -0.011      -0.002
# DELEGATION_PARLIAMENTARY             -0.0169      0.006     -3.044      0.002      -0.028      -0.006
# DELEGATION_PARLIAMENTARY_ASSEMBLY     0.0071      0.002      3.594      0.000       0.003       0.011
# WORKING_GROUP                         0.0139      0.005      2.739      0.006       0.004       0.024
# ==============================================================================
# Omnibus:                    57797.090   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         55003928.910
# Skew:                          13.754   Prob(JB):                         0.00
# Kurtosis:                     204.913   Cond. No.                     1.36e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.9e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Run panel regression with entity (MEP) fixed effects
model = PanelOLS(Y, X, entity_effects=True)
results_fe = model.fit()

print(results_fe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Run panel regression with entity (MEP) fixed effects
# ----> 2 model = PanelOLS(Y, X, entity_effects=True)
#       3 results_fe = model.fit()
#       5 print(results_fe)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\linearmodels\panel\model.py:1260, in PanelOLS.__init__(self, dependent, exog, weights, entity_effects, time_effects, other_effects, singletons, drop_absorbed, check_rank)
#    1247 def __init__(
#    1248     self,
#    1249     dependent: PanelDataLike,
#    (...)
#    1258     check_rank: bool = True,
#    1259 ) -> None:
# -> 1260     super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
#    1262     self._entity_effects = entity_effects
#    1263     self._time_effects = time_effects
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\linearmodels\panel\model.py:339, in _PanelModelBase.__init__(self, dependent, exog, weights, check_rank)
#     337 self._constant_index: int | None = None
#     338 self._check_rank = bool(check_rank)
# --> 339 self._validate_data()
#     340 self._singleton_index: linearmodels.typing.data.BoolArray | None = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\linearmodels\panel\model.py:494, in _PanelModelBase._validate_data(self)
#     492 w_df = w_df / w_df.mean()
#     493 self.weights = PanelData(w_df)
# --> 494 rank_of_x = self._check_exog_rank()
#     495 self._constant, self._constant_index = has_constant(x, rank_of_x)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\linearmodels\panel\model.py:447, in _PanelModelBase._check_exog_rank(self)
#     445 _, _, rank_of_x, _ = _lstsq(x, np.ones(x.shape[0]))
#     446 if rank_of_x < x.shape[1]:
# --> 447     raise ValueError(
#     448         "exog does not have full column rank. If you wish to proceed with "
#     449         "model estimation irrespective of the numerical accuracy of "
#     450         "coefficient estimates, you can set check_rank=False."
#     451     )
#     452 return rank_of_x
#
# ValueError: exog does not have full column rank. If you wish to proceed with model estimation irrespective of the numerical accuracy of coefficient estimates, you can set check_rank=False.
