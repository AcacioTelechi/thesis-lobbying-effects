# %%
# Compute authority and hub scores for lobbying network
import pandas as pd
import numpy as np
import networkx as nx
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm

# %%
df = pd.read_csv("./data/silver/df_meetings_lobbyists.csv")

# %%
lobbyist_topics_columns = [
    "l_agriculture",
    "l_economics_and_trade",
    "l_education",
    "l_environment_and_climate",
    "l_foreign_and_security_affairs",
    "l_health",
    "l_human_rights",
    "l_infrastructure_and_industry",
    "l_technology",
]

df_authorities = pd.DataFrame()
for date in tqdm(df["meeting_date"].sort_values().unique()):
    df_date = df[df["meeting_date"] <= date]
    G = nx.from_pandas_edgelist(
        df_date, source="lobbyist_id", target="member_id", create_using=nx.DiGraph()
    )

    # Use NetworkX's HITS implementation
    hubs, authorities = nx.hits(G)

    new_df_authorities = pd.DataFrame(
        [{"id": k, "date": date, "authority": v} for k, v in authorities.items()]
    )

    # compute cumulative topics
    df_cum_meetings_topics = (
        df_date[["member_id", *lobbyist_topics_columns]].groupby("member_id").sum()
    )

    df_cum_meetings_topics["total_topics_cum"] = df_cum_meetings_topics.sum(axis=1)

    df_cum_meetings_topics.reset_index(inplace=True)

    # for each lobbyist_topics_column. compute percentage of total topics
    for col in lobbyist_topics_columns:
        df_cum_meetings_topics[f"{col}_percentage"] = (
            df_cum_meetings_topics[col] / df_cum_meetings_topics["total_topics_cum"]
        )

    # compute authority * topic_percentage for each lobbyist_topics_column

    df_cum_meetings_topics = df_cum_meetings_topics.merge(
        new_df_authorities,
        left_on="member_id",
        right_on="id",
        how="left",
    )

    for col in lobbyist_topics_columns:
        df_cum_meetings_topics[f"{col}_authority_percentage"] = (
            df_cum_meetings_topics[f"{col}_percentage"]
            * df_cum_meetings_topics["authority"]
        )

    del df_cum_meetings_topics["id"]

    df_authorities = pd.concat([df_authorities, df_cum_meetings_topics])
# Out:
# 100%|██████████| 1396/1396 [01:57<00:00, 11.84it/s]

# %%
from datetime import datetime

df_authorities['Y-m'] = df_authorities['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').strftime('%Y-%m'))
df_authorities['Y-w'] = df_authorities['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').strftime('%Y-W%W'))


df_ym = df_authorities.copy()
del df_ym['Y-w']
del df_ym['date']
df_ym = df_ym.groupby(['member_id', 'Y-m']).median().reset_index()


df_yw = df_authorities.copy()
del df_yw['date']
del df_yw['Y-m']
df_yw = df_yw.groupby(['member_id', 'Y-w']).median().reset_index()

# %%
df_ym.describe().T
# Out:
#                                                       count        mean  \
# l_agriculture                                       28082.0   13.526351
# l_economics_and_trade                               28082.0   29.735115
# l_education                                         28082.0   16.343601
# l_environment_and_climate                           28082.0   27.415088
# l_foreign_and_security_affairs                      28082.0   24.115181
# l_health                                            28082.0   20.157645
# l_human_rights                                      28082.0   15.201036
# l_infrastructure_and_industry                       28082.0   28.024375
# l_technology                                        28082.0   27.267841
# total_topics_cum                                    28082.0  201.786233
# l_agriculture_percentage                            28082.0    0.066730
# l_economics_and_trade_percentage                    28082.0    0.147749
# l_education_percentage                              28082.0    0.082846
# l_environment_and_climate_percentage                28082.0    0.131916
# l_foreign_and_security_affairs_percentage           28082.0    0.126741
# l_health_percentage                                 28082.0    0.099092
# l_human_rights_percentage                           28082.0    0.079913
# l_infrastructure_and_industry_percentage            28082.0    0.133076
# l_technology_percentage                             28082.0    0.131887
# authority                                           28082.0    0.002269
# l_agriculture_authority_percentage                  28082.0    0.000148
# l_economics_and_trade_authority_percentage          28082.0    0.000336
# l_education_authority_percentage                    28082.0    0.000183
# l_environment_and_climate_authority_percentage      28082.0    0.000312
# l_foreign_and_security_affairs_authority_percen...  28082.0    0.000267
# l_health_authority_percentage                       28082.0    0.000224
# l_human_rights_authority_percentage                 28082.0    0.000172
# l_infrastructure_and_industry_authority_percentage  28082.0    0.000320
# l_technology_authority_percentage                   28082.0    0.000308
#
#                                                            std           min  \
# l_agriculture                                        24.245832  0.000000e+00
# l_economics_and_trade                                48.322843  0.000000e+00
# l_education                                          26.481876  0.000000e+00
# l_environment_and_climate                            46.468246  0.000000e+00
# l_foreign_and_security_affairs                       38.715920  0.000000e+00
# l_health                                             32.713500  0.000000e+00
# l_human_rights                                       26.585190  0.000000e+00
# l_infrastructure_and_industry                        47.923003  0.000000e+00
# l_technology                                         45.219566  0.000000e+00
# total_topics_cum                                    325.372926  1.000000e+00
# l_agriculture_percentage                              0.050747  0.000000e+00
# l_economics_and_trade_percentage                      0.040720  0.000000e+00
# l_education_percentage                                0.047781  0.000000e+00
# l_environment_and_climate_percentage                  0.050031  0.000000e+00
# l_foreign_and_security_affairs_percentage             0.052130  0.000000e+00
# l_health_percentage                                   0.042269  0.000000e+00
# l_human_rights_percentage                             0.054540  0.000000e+00
# l_infrastructure_and_industry_percentage              0.043536  0.000000e+00
# l_technology_percentage                               0.040990  0.000000e+00
# authority                                             0.006212 -1.248928e-17
# l_agriculture_authority_percentage                    0.000473 -1.624981e-18
# l_economics_and_trade_authority_percentage            0.000846 -2.523972e-18
# l_education_authority_percentage                      0.000375 -1.786230e-18
# l_environment_and_climate_authority_percentage        0.001012 -1.569393e-18
# l_foreign_and_security_affairs_authority_percen...    0.000688 -2.497856e-18
# l_health_authority_percentage                         0.000679 -1.786230e-18
# l_human_rights_authority_percentage                   0.000386 -1.786230e-18
# l_infrastructure_and_industry_authority_percentage    0.001014 -1.916848e-18
# l_technology_authority_percentage                     0.000887 -2.497856e-18
#
#                                                           25%        50%  \
# l_agriculture                                        1.000000   5.000000
# l_economics_and_trade                                4.000000  12.000000
# l_education                                          2.000000   6.000000
# l_environment_and_climate                            3.000000  10.000000
# l_foreign_and_security_affairs                       4.000000  10.000000
# l_health                                             3.000000   8.000000
# l_human_rights                                       2.000000   6.000000
# l_infrastructure_and_industry                        3.000000  11.000000
# l_technology                                         4.000000  11.000000
# total_topics_cum                                    28.000000  81.000000
# l_agriculture_percentage                             0.032787   0.059122
# l_economics_and_trade_percentage                     0.130864   0.147541
# l_education_percentage                               0.054545   0.081081
# l_environment_and_climate_percentage                 0.109705   0.131325
# l_foreign_and_security_affairs_percentage            0.106061   0.123791
# l_health_percentage                                  0.081081   0.100535
# l_human_rights_percentage                            0.041420   0.076923
# l_infrastructure_and_industry_percentage             0.115385   0.135135
# l_technology_percentage                              0.115819   0.134021
# authority                                            0.000273   0.001067
# l_agriculture_authority_percentage                   0.000010   0.000056
# l_economics_and_trade_authority_percentage           0.000039   0.000153
# l_education_authority_percentage                     0.000018   0.000082
# l_environment_and_climate_authority_percentage       0.000031   0.000143
# l_foreign_and_security_affairs_authority_percen...   0.000033   0.000129
# l_health_authority_percentage                        0.000024   0.000104
# l_human_rights_authority_percentage                  0.000015   0.000071
# l_infrastructure_and_industry_authority_percentage   0.000033   0.000136
# l_technology_authority_percentage                    0.000034   0.000132
#
#                                                            75%          max
# l_agriculture                                        15.000000   260.000000
# l_economics_and_trade                                35.000000   612.000000
# l_education                                          20.000000   395.000000
# l_environment_and_climate                            32.000000   582.000000
# l_foreign_and_security_affairs                       29.000000   527.000000
# l_health                                             24.000000   433.000000
# l_human_rights                                       17.000000   416.000000
# l_infrastructure_and_industry                        32.000000   586.000000
# l_technology                                         32.000000   577.000000
# total_topics_cum                                    239.000000  4274.000000
# l_agriculture_percentage                              0.094333     0.500000
# l_economics_and_trade_percentage                      0.163082     1.000000
# l_education_percentage                                0.111111     0.500000
# l_environment_and_climate_percentage                  0.157567     1.000000
# l_foreign_and_security_affairs_percentage             0.142857     1.000000
# l_health_percentage                                   0.121622     1.000000
# l_human_rights_percentage                             0.111111     0.500000
# l_infrastructure_and_industry_percentage              0.153846     1.000000
# l_technology_percentage                               0.151052     1.000000
# authority                                             0.002682     0.449187
# l_agriculture_authority_percentage                    0.000162     0.029552
# l_economics_and_trade_authority_percentage            0.000403     0.059781
# l_education_authority_percentage                      0.000215     0.017934
# l_environment_and_climate_authority_percentage        0.000358     0.076835
# l_foreign_and_security_affairs_authority_percen...    0.000324     0.047825
# l_health_authority_percentage                         0.000265     0.053803
# l_human_rights_authority_percentage                   0.000202     0.023912
# l_infrastructure_and_industry_authority_percentage    0.000370     0.076835
# l_technology_authority_percentage                     0.000357     0.065759

# %%
df_authorities.to_csv("./data/gold/panel_data_graph_v020704.csv", index=False)
df_ym.to_csv("./data/gold/panel_data_graph_Ym_v020704.csv", index=False)
df_yw.to_csv("./data/gold/panel_data_graph_Yw_v020704.csv", index=False)
